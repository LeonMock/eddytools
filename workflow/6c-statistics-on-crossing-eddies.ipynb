# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# parameters
minimum_duration = 5
first_or_last_crossing = 'first'

experiment_name = 'INALT20r.L120-KRS006'#'INALT60.L120-KRS0020'
data_resolution = '1d'

tracking_start = "2012-01-01"
tracking_end = "2012-12-31"

# %%
# detection parameters
OW_thr_factor =-0.3
if experiment_name.startswith("INALT60"):
    Npix_min, Npix_max = 720, 18000
    sigma = 15
    wx = 600
elif experiment_name.startswith("INALT20"):
    Npix_min, Npix_max = 80, 2000
    sigma = 5
    wx = 200

# %%
depth= 0  #corresponding to... 
depth_index = 0 # tracking only on surface

# %%
outpath = f'/gxfs_work/geomar/smomw523/eddytools/results/{experiment_name}/smoothed/{sigma}/{data_resolution}/depth-{depth}/'   ## !! SMOOTHED !!

# %%
df = pd.read_csv(outpath + f'Good-hope-{first_or_last_crossing}-crossings_min-{minimum_duration}d_{tracking_start.replace("-", "")}_{tracking_end.replace("-", "")}_OW{np.abs(OW_thr_factor)}_Npix-{Npix_min}-{Npix_max}_rolling-{wx}.csv')

# %%
df
# Out:
#             type        lon        lat        time  duration           amp  \
# 0   anticyclonic   6.516543 -36.717485  2012-02-15       365  1.461926e-05
# 1   anticyclonic  13.560201 -34.897697  2012-01-16        27  9.673480e-06
# 2       cyclonic  12.677382 -32.983831  2012-01-07        40  3.365140e-06
# 3       cyclonic   8.959236 -42.050576  2012-01-16        38  1.164659e-06
# 4   anticyclonic   8.868758 -32.950874  2012-07-07       348  8.997802e-06
# 5   anticyclonic  13.405702 -35.085775  2012-03-11       348  1.249102e-05
# 6       cyclonic  13.842615 -34.507415  2012-02-08        64  1.145027e-05
# 7   anticyclonic  12.977616 -35.707528  2012-01-26        16  1.403751e-05
# 8       cyclonic   8.456866 -32.980488  2012-01-30        17  9.353769e-07
# 9   anticyclonic  17.181798 -32.999764  2012-02-14        14  4.105760e-06
# 10  anticyclonic   9.875844 -32.981822  2012-03-28       203  1.131229e-05
# 11  anticyclonic  10.281577 -40.029637  2012-02-17        14  1.570152e-06
# 12      cyclonic  15.668046 -34.318783  2012-02-23        40  6.214655e-06
# 13  anticyclonic   5.742788 -38.651273  2012-06-26       146  3.533565e-06
# 14      cyclonic   9.265430 -41.562893  2012-04-04        44  1.691605e-06
# 15      cyclonic  13.459153 -34.907237  2012-03-27         7  2.833175e-06
# 16  anticyclonic   9.418963 -41.314840  2012-03-26         7  2.139095e-06
# 17  anticyclonic   7.747414 -43.863824  2012-04-30        44  3.363891e-06
# 18      cyclonic  10.953043 -32.970541  2012-04-08        10  1.917421e-06
# 19  anticyclonic  16.667342 -32.979719  2012-04-07         8  1.723248e-06
# 20      cyclonic   6.745456 -36.220480  2012-05-12        49  2.837226e-06
# 21      cyclonic  16.610834 -32.896518  2012-05-10        33  4.067753e-06
# 22      cyclonic  12.580276 -36.494222  2012-06-30        87  8.075598e-06
# 23  anticyclonic   6.857031 -36.007994  2012-09-08       253  9.494499e-06
# 24  anticyclonic  12.265220 -36.941816  2012-05-31       253  1.321492e-05
# 25  anticyclonic  16.046174 -32.969075  2012-04-25        20  1.295283e-06
# 26      cyclonic  15.240528 -34.363568  2012-06-29       201  9.250332e-06
# 27  anticyclonic   6.322293 -37.182497  2012-05-12         5  7.076852e-07
# 28  anticyclonic   9.351016 -41.440142  2012-05-22        62  1.771408e-06
# 25  25.518125   2045.725629           False        True  Schmidt-GHS
# 26  41.038872   5291.035852           False        True  Ansorge-GHS
# 27  22.492836   1589.418705           False        True  Schmidt-GHS
# 28  27.122738   2311.090440           False        True  Ansorge-GHS
# 29  46.384632   6759.243773           False        True  Schmidt-GHS
# 30  22.016537   1522.817642           False        True  Schmidt-GHS
# 31  25.766462   2085.736584           False        True  Schmidt-GHS
# 32  48.092856   7266.261368           False        True  Ansorge-GHS
# 33  81.544997  20890.291983           False       False  Ansorge-GHS
# 34  40.596498   5177.582248           False        True  Schmidt-GHS
# 35  46.870901   6901.706425           False        True  Schmidt-GHS
# 36  25.653457   2067.481649           False        True  Ansorge-GHS
# 37  26.404246   2190.268848           False        True  Schmidt-GHS
# 38  24.911224   1949.575317           False        True  Schmidt-GHS
# 39  73.274092  16867.501654           False       False  Schmidt-GHS
# 40  72.114034  16337.645047           False       False  Ansorge-GHS
# 41  50.580659   8037.460158           False       False  Schmidt-GHS
# 42  28.853335   2615.422887           False        True  Ansorge-GHS
# 43  40.089613   5049.095692           False        True  Schmidt-GHS
# 44  26.087757   2138.076992           False        True  Schmidt-GHS
# 45  45.653032   6547.705208           False        True  Schmidt-GHS
# 46  54.169388   9218.446143           False        True  Ansorge-GHS
# 47  79.382316  19796.910001           False       False  Ansorge-GHS
# 48  77.585160  18910.682027           False        True  Ansorge-GHS
# 49  30.524322   2927.129432           False        True  Ansorge-GHS
# 50  51.967875   8484.373566           False       False  Ansorge-GHS
# 51  34.332860   3703.137564           False       False  Ansorge-GHS

# %%
hist_columns = ['duration', 'amp', 'scale', 'area']
titles = ['duration [days]', 'vorticity amplitude', 'average radius [km] ', 'area [km²]']
type_colors = {'cyclonic': 'blue', 'anticyclonic': 'red'}
sections = ['Ansorge-GHS', 'Schmidt-GHS']

fig, axes = plt.subplots(2, 4, figsize=(18, 8))  # 2 Reihen, 4 Spalten
axes = axes.flatten()

for j, section in enumerate(sections):
    df_section = df[df['section'] == section]
    
    for i, col in enumerate(hist_columns):
        bins = np.histogram_bin_edges(df[col], bins='auto')
        bins = np.linspace(np.round(bins[0] / (10 ** np.round(np.log10(bins[0]))), 1) * 10 ** np.round(np.log10(bins[0])),
                           np.round(bins[-1] / (10 ** np.round(np.log10(bins[-1]))), 1) * 10 ** np.round(np.log10(bins[-1])), 11)
        
        for type_label, color in type_colors.items():
            sns.histplot(df_section[df_section['type'] == type_label][col], bins=bins, kde=True, line_kws={'linewidth': 3},
                         label=type_label, ax=axes[i + j * 4], color=color, alpha=0.4)
        
        #axes[i].set_title(f'{col}',fontsize=20)
        axes[i+j*4].set_xlabel(f'{titles[i]}',fontsize=15)
        axes[i+j*4].set_ylabel('')
        #axes[i+j*4].legend()

    print(f'{section}, existed at start: {np.round(100*df_section["exist_at_start"].sum()/len(df_section),1)}%')
    print(f'{section}, not terminated at end: {100-np.round(100*df_section["terminated"].sum()/len(df_section),1)}%')

plt.tight_layout()
plt.show()
# Out:
# Ansorge-GHS, existed at start: 3.8%
# Ansorge-GHS, not terminated at end: 26.900000000000006%
# Schmidt-GHS, existed at start: 7.7%
# Schmidt-GHS, not terminated at end: 19.200000000000003%

# %%
df_section['exist_at_start'].sum()/len(df_section)
# Out:
# 0.06666666666666667
