# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# parameters
minimum_duration = 5
first_or_last_crossing = 'first'

# detection parameters
Npix_min = 2025 #20*6*5
Npix_max = 15000 #500*6*5
OW_thr_factor =-0.3

sigma = 9 # smoothing parameter
wx = 1500 # rolling window size in x-direction

experiment_name = 'INALT60.L120-KRS0020'
data_resolution = '1d'

tracking_start = "2012-01-01"
tracking_end = "2012-12-15"

# %%
depth= 0  #corresponding to... 
depth_index = 0 # tracking only on surface

# %%
outpath = f'/gxfs_work/geomar/smomw523/eddytools/results/{experiment_name}/smoothed/{sigma}/{data_resolution}/depth-{depth}/'   ## !! SMOOTHED !!

# %%
df = pd.read_csv(outpath + f'Good-hope-{first_or_last_crossing}-crossings_min-{minimum_duration}d_{tracking_start.replace("-", "")}_{tracking_end.replace("-", "")}_OW{np.abs(OW_thr_factor)}_Npix-{Npix_min}-{Npix_max}_rolling-{wx}.csv')

# %%
df
# Out:
#             type        lon        lat        time  duration       amp  \
# 0   anticyclonic  10.053439 -40.134329  2012-01-19        22  0.000024
# 1   anticyclonic   7.853921 -33.496286  2012-02-04       270  0.000018
# 2       cyclonic  16.509102 -34.331776  2012-01-16        15  0.000015
# 3       cyclonic  11.925286 -37.649544  2012-03-01        57  0.000023
# 4   anticyclonic  11.228311 -38.525100  2012-03-17        63  0.000016
# 5   anticyclonic  15.364293 -33.053165  2012-01-22       118  0.000008
# 6   anticyclonic  13.092701 -34.995170  2012-03-25        21  0.000017
# 7       cyclonic  11.850430 -37.603865  2012-03-20        12  0.000016
# 8       cyclonic  14.239702 -34.265685  2012-03-21         8  0.000014
# 9   anticyclonic   6.611004 -36.500417  2012-04-07        53  0.000012
# 10      cyclonic  13.781559 -34.384333  2012-03-29        21  0.000012
# 11      cyclonic  11.793244 -37.641458  2012-04-01        72  0.000028
# 12  anticyclonic   8.764292 -32.930658  2012-07-21       165  0.000010
# 13      cyclonic   5.833017 -38.491949  2012-04-24        75  0.000006
# 14  anticyclonic   6.951383 -35.745490  2012-08-04       116  0.000012
# 15  anticyclonic  12.797957 -36.146056  2012-05-04       116  0.000011
# 16  anticyclonic   8.036432 -33.210930  2012-05-27        55  0.000006
# 17  anticyclonic  11.134349 -38.571885  2012-07-15        40  0.000023
# 18  anticyclonic  15.891029 -34.308878  2012-06-22        16  0.000010
# 19  anticyclonic   9.732022 -40.736292  2012-07-09        25  0.000024
# 20      cyclonic  15.404097 -32.993481  2012-07-01        13  0.000029
# 21  anticyclonic   4.878186 -40.563079  2012-07-13        16  0.000005
# 22  anticyclonic  14.300689 -34.306066  2012-07-18        10  0.000008
# 23  anticyclonic  11.509479 -38.275819  2012-07-24        22  0.000015
# 24  anticyclonic  11.531220 -37.824293  2012-08-13        11  0.000017
# 25  anticyclonic  11.721946 -37.513716  2012-08-27        10  0.000011
# 26  anticyclonic   8.860968 -32.882980  2012-08-30        19  0.000012
# 27  anticyclonic  12.922786 -35.372009  2012-08-31         8  0.000011
# 28  anticyclonic  13.018811 -35.229579  2012-09-21        24  0.000014
# 29  anticyclonic  13.775721 -34.458898  2012-09-27         5  0.000016
# 30  anticyclonic  13.290326 -35.209214  2012-10-05         5  0.000013
# 31  anticyclonic   6.395173 -36.967513  2012-10-12         7  0.000005
# 32      cyclonic   4.200977 -42.194944  2012-10-21        21  0.000008
# 33      cyclonic   8.252480 -33.061116  2012-10-29        13  0.000005
# 34  anticyclonic   5.091405 -40.134805  2012-12-11        51  0.000017
# 35  anticyclonic  12.313975 -36.934149  2012-11-03        51  0.000009
# 36  anticyclonic  10.835630 -39.149890  2012-11-18        40  0.000021
# 37  anticyclonic  11.903800 -32.969804  2012-12-09        33  0.000012
# 38      cyclonic  11.512125 -38.084253  2012-11-25        28  0.000020
#
#         scale          area  exist_at_start  terminated      section
# 0   40.122329   5057.339871            True        True  Ansorge-GHS
# 1   58.325992  10687.450936            True        True  Schmidt-GHS
# 2   51.105477   8205.116769           False        True  Ansorge-GHS
# 3   47.398904   7058.078338           False        True  Ansorge-GHS
# 4   40.599943   5178.461110           False        True  Ansorge-GHS
# 5   73.288523  16874.146372           False        True  Schmidt-GHS
# 6   62.431662  12245.024662           False        True  Ansorge-GHS
# 7   47.928938   7216.813687           False        True  Ansorge-GHS
# 8   45.124486   6396.971437           False        True  Ansorge-GHS
# 9   68.399807  14698.046964           False        True  Schmidt-GHS
# 10  69.434144  15145.933247           False        True  Ansorge-GHS
# 11  74.848029  17599.916603           False        True  Ansorge-GHS
# 12  72.653855  16583.156602           False        True  Schmidt-GHS
# 13  52.911321   8795.227440           False        True  Schmidt-GHS
# 14  76.233031  18257.287127           False        True  Schmidt-GHS
# 15  80.990104  20606.953196           False        True  Ansorge-GHS
# 16  63.710427  12751.782804           False        True  Schmidt-GHS
# 17  43.420658   5923.012935           False        True  Ansorge-GHS
# 18  46.334572   6744.661778           False        True  Ansorge-GHS
# 19  48.902203   7512.884725           False        True  Ansorge-GHS
# 20  51.226089   8243.891746           False        True  Schmidt-GHS
# 21  46.352760   6749.957863           False        True  Schmidt-GHS
# 22  43.248012   5876.005092           False        True  Ansorge-GHS
# 23  61.619744  11928.604911           False        True  Ansorge-GHS
# 24  44.068524   6101.082258           False        True  Ansorge-GHS
# 25  44.754706   6292.558965           False        True  Ansorge-GHS
# 26  59.948023  11290.147148           False        True  Schmidt-GHS
# 27  62.315067  12199.330651           False        True  Ansorge-GHS
# 28  66.817786  14026.006287           False        True  Ansorge-GHS
# 29  41.488005   5407.480688           False        True  Ansorge-GHS
# 30  61.089795  11724.307886           False        True  Ansorge-GHS
# 31  38.104807   4561.518241           False        True  Schmidt-GHS
# 32  36.269883   4132.779025           False        True  Schmidt-GHS
# 33  51.886771   8457.912158           False        True  Schmidt-GHS
# 34  43.701650   5999.921269           False       False  Schmidt-GHS
# 35  45.528336   6511.985674           False       False  Ansorge-GHS
# 36  61.424433  11853.106328           False       False  Ansorge-GHS
# 37  68.576209  14773.956468           False       False  Schmidt-GHS
# 38  59.811526  11238.792296           False       False  Ansorge-GHS

# %%
hist_columns = ['duration', 'amp', 'scale', 'area']
titles = ['duration [days]', 'vorticity amplitude', 'average radius [km] ', 'area [km²]']
type_colors = {'cyclonic': 'blue', 'anticyclonic': 'red'}
sections = ['Ansorge-GHS', 'Schmidt-GHS']

fig, axes = plt.subplots(2, 4, figsize=(18, 8))  # 2 Reihen, 4 Spalten
axes = axes.flatten()

for j, section in enumerate(sections):
    df_section = df[df['section'] == section]
    
    for i, col in enumerate(hist_columns):
        bins = np.histogram_bin_edges(df[col], bins='auto')
        bins = np.linspace(np.round(bins[0] / (10 ** np.round(np.log10(bins[0]))), 1) * 10 ** np.round(np.log10(bins[0])),
                           np.round(bins[-1] / (10 ** np.round(np.log10(bins[-1]))), 1) * 10 ** np.round(np.log10(bins[-1])), 11)
        
        for type_label, color in type_colors.items():
            sns.histplot(df_section[df_section['type'] == type_label][col], bins=bins, kde=True, line_kws={'linewidth': 3},
                         label=type_label, ax=axes[i + j * 4], color=color, alpha=0.4)
        
        #axes[i].set_title(f'{col}',fontsize=20)
        axes[i+j*4].set_xlabel(f'{titles[i]}',fontsize=15)
        axes[i+j*4].set_ylabel('')
        #axes[i+j*4].legend()

    print(f'{section}, existed at start: {np.round(100*df_section["exist_at_start"].sum()/len(df_section),1)}%')
    print(f'{section}, not terminated at end: {100-np.round(100*df_section["terminated"].sum()/len(df_section),1)}%')

plt.tight_layout()
plt.show()
# Out:
# Ansorge-GHS, existed at start: 4.2%
# Ansorge-GHS, not terminated at end: 12.5%
# Schmidt-GHS, existed at start: 6.7%
# Schmidt-GHS, not terminated at end: 13.299999999999997%

# %%
df_section['exist_at_start'].sum()/len(df_section)
# Out:
# 0.06666666666666667
